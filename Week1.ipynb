# %%
# Langkah 1: Import Library
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"
        ]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F0B740CF0D0>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F0B73C2DD90>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F0B73BD7B90>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print(f"Resolusi image: $d x $d".format(tinggi, lebar))
cv2_imshow(image_2)
# Out:
# Resolusi image: $d x $d
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F0B740CFC90>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# garis horizontal
for y in range(lebar):
  image_3[int(tinggi/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F0B73BD7A10>

# %% [markdown]
# **Pertanyaan**
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
#     image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# 4. Apakah kegunaan kode [255,255,255] ? Jelaskan!
#     for y in range(lebar):
#       image_3[int((tinggi)/2), y] = [255,255,255]
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# **Jawaban**
# 1. Untuk memudahkan mahasiswa dalam menjalankan praktikum, karena google collab tidak membutuhkan spesifikasi tertentu
# 2.
#     1. numpy: untuk memanipulasi array yang mana array ini untuk menyimpan pixel pada foto
#     2. pandas: untuk memanipulasi data
#     3. cv2: untuk kebutuhan computer vision seperti mengkonversi warna, mengubah ukuran gambar
#     4. skimage: untuk image processing, salah satu contohnya untuk input gambar menggunakan io
#     5. matplotlib: untuk melakukan fungsi-fungsi tertentu yang ada pada matlab, seperti plot, show, dll
# 3. Untuk memperkecil ukuran gambar menjadi setengah dari ukuran aslinya, hal ini ditandai dengan adanya fx=0.5, dan fy=0.5.
# 4. [255,255,255] merupakan warna putih dalam RGB, pada langkah tersebut dilakukan untuk mengubah array pixel pada image_3 menjadi sebuah warna putih yang nantinya akan menjadi sebuah garis karena dilakukan perulanagan
# 5. pixel merupakan satuan nilai yang mewakili suatu warna pada sebuah gambar, sedangkan resolusi ada kerapatan sebuah pixel.

# %% [markdown]
# **Tugas**

# %% [markdown]
# 1. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F0B71A52310>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (0,0), (lebar, tinggi), (255,255,255), 2)
cv.line(image_3, (lebar,0), (0, tinggi), (255,255,255), 2)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F0B71A52190>
